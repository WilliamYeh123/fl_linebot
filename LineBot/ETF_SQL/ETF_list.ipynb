# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_excel("ETF_list.xlsx")
conn = sqlite3.connect('ETF_list.db')  #建立資料庫
cursor = conn.cursor()
cursor.execute('''CREATE TABLE ETF_list(Type TEXT, Number TEXT PRIMARY KEY, Name TEXT);''')
#cursor.execute('CREATE TABLE ETF_list1(Type, Number, Name);')  #建立資料表
conn.commit()
#conn.close()

#如果資料表存在，就寫入資料，否則建立資料表
df.to_sql('ETF_list', conn, if_exists='append', index=False)

# %%
conn = sqlite3.connect('ETF_list.db')  #建立資料庫
cursor = conn.cursor()
cursor.execute('''SELECT * FROM ETF_list;''')
rows = cursor.fetchall()
print(rows)
#cursor.execute('CREATE TABLE ETF_list1(Type, Number, Name);')  #建立資料表
#conn.commit()
#conn.close()

#如果資料表存在，就寫入資料，否則建立資料表
#df.to_sql('ETF_list', conn, if_exists='append', index=False)
# Out:
# [('國內成分證券ETF', '0050', '元大台灣50'), ('國內成分證券ETF', '0051', '元大中型100'), ('國內成分證券ETF', '0052', '富邦科技'), ('國內成分證券ETF', '0053', '元大電子'), ('國內成分證券ETF', '0054', '元大台商50'), ('國內成分證券ETF', '0055', '元大MSCI金融'), ('國內成分證券ETF', '0056', '元大高股息'), ('國內成分證券ETF', '0057', '富邦摩台'), ('國內成分證券ETF', '006203', '元大MSCI台灣'), ('國內成分證券ETF', '006204', '永豐臺灣加權'), ('國內成分證券ETF', '006208', '富邦台50'), ('國內成分證券ETF', '00690', '兆豐藍籌30'), ('國內成分證券ETF', '00692', '富邦公司治理'), ('國內成分證券ETF', '00701', '國泰股利精選30'), ('國內成分證券ETF', '00713', '元大台灣高息低波'), ('國內成分證券ETF', '00730', '富邦臺灣優質高息'), ('國內成分證券ETF', '00728', '第一金工業30'), ('國內成分證券ETF', '00731', 'FH富時高息低波'), ('國內成分證券ETF', '00733', '富邦臺灣中小'), ('國內成分證券ETF', '00850', '元大臺灣ESG永續'), ('國內成分證券ETF', '00878', '國泰永續高股息'), ('國內成分證券ETF', '00881', '國泰台灣5G+\t'), ('國內成分證券ETF', '00891', '中信關鍵半導體'), ('國內成分證券ETF', '00892', '富邦台灣半導體\t'), ('國內成分證券ETF', '00894', '中信小資高價30\t'), ('國內成分證券ETF', '00896', '中信綠能及電動車\t'), ('國內成分證券ETF', '00901', '永豐智能車供應鏈\t'), ('國內成分證券ETF', '00900', '富邦特選高股息30'), ('國內成分證券ETF', '00904', '新光臺灣半導體30'), ('國內成分證券ETF', '00905', 'FT臺灣Smart'), ('國內成分證券ETF', '00907', '永豐優息存股'), ('國外成分證券ETF', '0061', '元大寶滬深'), ('國外成分證券ETF', '006205', '富邦上証(新臺幣)'), ('國外成分證券ETF', '00625K', '富邦上証+R(人民幣)'), ('國外成分證券ETF', '006206', '元大上證50'), ('國外成分證券ETF', '006207', 'FH滬深'), ('國外成分證券ETF', '00636', '國泰中國A50(新臺幣)'), ('國外成分證券ETF', '00636K', '國泰中國A50+U(美元)'), ('國外成分證券ETF', '00639', '富邦深100'), ('國外成分證券ETF', '00645', '富邦日本'), ('國外成分證券ETF', '00643', '群益深証中小(新臺幣)'), ('國外成分證券ETF', '00643K', '群益深証中小+R(人民幣)'), ('國外成分證券ETF', '00646', '元大S&P500'), ('國外成分證券ETF', '00652', '富邦印度'), ('國外成分證券ETF', '00657', '國泰日經225(新臺幣)'), ('國外成分證券ETF', '00657K', '國泰日經225+U(美元)'), ('國外成分證券ETF', '00661', '元大日經225'), ('國外成分證券ETF', '00662', '富邦NASDAQ'), ('國外成分證券ETF', '00668', '國泰美國道瓊(新臺幣)'), ('國外成分證券ETF', '00668K', '國泰美國道瓊+U(美元)'), ('國外成分證券ETF', '00678', '群益NBI生技'), ('國外成分證券ETF', '00700', '富邦恒生國企(原簡稱：富邦H股)'), ('國外成分證券ETF', '00703', '台新MSCI中國'), ('國外成分證券ETF', '00709', '富邦歐洲'), ('國外成分證券ETF', '00702', '國泰標普低波高息'), ('國外成分證券ETF', '00710B', 'FH彭博高收益債'), ('國外成分證券ETF', '00711B', 'FH彭博新興債'), ('國外成分證券ETF', '00712', 'FH富時不動產'), ('國外成分證券ETF', '00714', '群益道瓊美國地產'), ('國外成分證券ETF', '00717', '富邦美國特別股'), ('國外成分證券ETF', '00732', '國泰RMB短期報酬\t'), ('國外成分證券ETF', '00735', '國泰臺韓科技\t'), ('國外成分證券ETF', '00736', '國泰新興市場'), ('國外成分證券ETF', '00737', '國泰AI+Robo'), ('國外成分證券ETF', '00739', '元大MSCI A股'), ('國外成分證券ETF', '00743', '國泰中國A150\t'), ('國外成分證券ETF', '00752', '中信中國50'), ('國外成分證券ETF', '00757', '統一FANG+\t'), ('國外成分證券ETF', '00762', '元大全球AI\t'), ('國外成分證券ETF', '00770', '國泰北美科技'), ('國外成分證券ETF', '00775B', '新光投等債15+\t'), ('國外成分證券ETF', '00774B', '新光中國政金綠債(新臺幣)'), ('國外成分證券ETF', '00774C', '新光中政金綠債+R(人民幣)\t'), ('國外成分證券ETF', '00783', '富邦中証500'), ('國外成分證券ETF', '00830', '國泰費城半導體'), ('國外成分證券ETF', '00771', '元大US高息特別股'), ('國外成分證券ETF', '00851', '台新全球AI\t'), ('國外成分證券ETF', '00861', '元大全球未來通訊'), ('國外成分證券ETF', '00865B', '國泰US短期公債'), ('國外成分證券ETF', '00875', '國泰網路資安'), ('國外成分證券ETF', '00876', '元大未來關鍵科技\t'), ('國外成分證券ETF', '00882', '中信中國高股息\t'), ('國外成分證券ETF', '00885', '富邦越南\t'), ('國外成分證券ETF', '00893', '國泰智能電動車'), ('國外成分證券ETF', '00895', '富邦未來車'), ('國外成分證券ETF', '00097', '富邦基因免疫生技'), ('國外成分證券ETF', '00898', '國泰基因免疫革命'), ('國外成分證券ETF', '00899', 'FT潔淨能源'), ('國外成分證券ETF', '00903', '富邦元宇宙'), ('國外成分證券ETF', '00902', '中信電池及儲能'), ('國外成分證券ETF', '00906', '大華元宇宙科技50'), ('國外成分證券ETF', '00908', '富邦入息REITs+'), ('槓桿型及反向型ETF', '00631L', '元大台灣50正2'), ('槓桿型及反向型ETF', '00632R', '元大台灣50反1'), ('槓桿型及反向型ETF', '00633L', '富邦上証正2'), ('槓桿型及反向型ETF', '00634R', '富邦上証反1'), ('槓桿型及反向型ETF', '00637L', '元大滬深300正2'), ('槓桿型及反向型ETF', '00638R', '元大滬深300反1'), ('槓桿型及反向型ETF', '00640L', '富邦日本正2'), ('槓桿型及反向型ETF', '00641R', '富邦日本反1'), ('槓桿型及反向型ETF', '00647L', '元大S&P500正2'), ('槓桿型及反向型ETF', '00648R', '元大S&P500反1'), ('槓桿型及反向型ETF', '00650L', 'FH香港正2'), ('槓桿型及反向型ETF', '00651R', 'FH香港反1'), ('槓桿型及反向型ETF', '00655L', '國泰中國A50正2'), ('槓桿型及反向型ETF', '00656R', '國泰中國A50反1'), ('槓桿型及反向型ETF', '00653L', '富邦印度正2'), ('槓桿型及反向型ETF', '00654R', '富邦印度反1'), ('槓桿型及反向型ETF', '00663L', '國泰臺灣加權正2'), ('槓桿型及反向型ETF', '00664R', '國泰臺灣加權反1'), (' ...
